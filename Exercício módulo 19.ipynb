# %% [markdown]
# # **MÓDULO 19**
# # Exercício: Estatística Aplicada

# %% [markdown]
# **Efetividade de Duas Estratégias de Ensino**
#
# Imagine que uma escola esteja avaliando a eficácia de duas estratégias de ensino de matemática para alunos do ensino médio. Eles querem determinar se há uma diferença significativa no desempenho médio dos alunos entre as duas estratégias.

# %% [markdown]
# # **Hipóteses:**
#
# * Hipótese nula (H0): A média das notas dos alunos na estratégia A é igual à média das notas dos alunos na estratégia B.
# * Hipótese alternativa (H1): A média das notas na Estratégia B é maior do que a média das notas na Estratégia A.

# %% [markdown]
# # **Dados:**
#
# * Amostra da Estratégia A: Notas de 50 alunos que receberam a Estratégia A.
# * Amostra da Estratégia B: Notas de 50 alunos que receberam a Estratégia B.

# %% [markdown]
# Usaremos um teste Z para comparar as médias das notas entre as duas amostras.

# %% [markdown]
# Se o p-valor do teste Z for menor que um nível de significância pré-determinado (por exemplo, α = 0.05), rejeitamos a hipótese nula e concluímos que há uma diferença significativa nas médias das notas entre as duas estratégias de ensino.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy import stats

# %% [markdown]
# Os dados são criados a seguir:

# %%
# Definindo médias e desvios padrão para as notas nas duas estratégias
media_estrategia_A = 70
desvio_padrao_estrategia_A = 10

media_estrategia_B = 75
desvio_padrao_estrategia_B = 12

# Gerando as amostras de notas para cada estratégia de ensino da nossa base
np.random.seed(0)  # Para garantir a reprodutibilidade dos resultados
amostra_estrategia_A = np.random.normal(loc=media_estrategia_A, scale=desvio_padrao_estrategia_A, size=50)
amostra_estrategia_B = np.random.normal(loc=media_estrategia_B, scale=desvio_padrao_estrategia_B, size=50)

print("Notas da Estratégia A:", amostra_estrategia_A[:5])
print("Notas da Estratégia B:", amostra_estrategia_B[:5])
# Out:
# Notas da Estratégia A: [87.64052346 74.00157208 79.78737984 92.40893199 88.6755799 ]
# Notas da Estratégia B: [64.25440127 79.64282997 68.87033835 60.83241379 74.66181326]

# %% [markdown]
# # 1) De acordo com as informações analisadas o nosso teste é unilateral á direita, esquerda ou bicaudal? Justifique.

# %% [markdown]
# - O teste é **unilateral à direita**, porque **H1** sugere que a média das notas da **estratégia B** é **maior** do que a média das notas da estratégia A (**B > A**).
# - Embora as 5 primeiras ocorrências de notas da estratégia A sejam maiores do que as 5 primeiras ocorrências de notas da estratégia B (o que poderia nos levar a tomar conclusões equivocadas), a análise deve considerar a média total das amostras, ou seja, todas as 50 ocorrências.

# %% [markdown]
# # 2) Calcule as médias para as duas amostragens e as variâncias. Quais insights você pode retirar comparando os dados?

# %%
import math # para utilizar a função .sqrt()

# Médias das Amostragens
media_amostragem_A = amostra_estrategia_A.mean()
media_amostragem_B = amostra_estrategia_B.mean()
print(f"Média amostragem de dados estratégia A: {media_amostragem_A:.2f}") # arredondamento para duas casa decimais
print(f"Média amostragem de dados estratégia B: {media_amostragem_B:.2f}") # arredondamento para duas casa decimais

# Variâncias/Desvios Padrão das Amostragens
var_amostragem_A = amostra_estrategia_A.var(ddof=1)
var_amostragem_B = amostra_estrategia_B.var(ddof=1)
print(f"Variância amostragem de dados estratégia A: {var_amostragem_A:.2f}; Desvio Padrão: {math.sqrt(var_amostragem_A):.2f}") # código para raiz quadrada e arredondamento para duas casa decimais
print(f"Variância amostragem de dados estratégia B: {var_amostragem_B:.2f}; Desvio Padrão: {math.sqrt(var_amostragem_B):.2f}") # código para raiz quadrada e arredondamento para duas casa decimais
# Out:
# Média amostragem de dados estratégia A: 71.41
# Média amostragem de dados estratégia B: 74.75
# Variância amostragem de dados estratégia A: 129.27; Desvio Padrão: 11.37
# Variância amostragem de dados estratégia B: 110.47; Desvio Padrão: 10.51

# %% [markdown]
# - Podemos verificar que a média de notas da **estratégia B** é **maior** que a média da estratégia A (**74.75 > 71.41**), o que pode sugerir que a estratégia B pode ser mais eficaz no ensino de matemática.
# - É possível verificar também que a variância e desvio padrão da **estratégia A** apresentam uma **dispersão ligeiramente maior** em comparação à estratégia B. Isso nos mostra que as notas da **estratégia B** estão **mais próximas** da média, o que representa uma maior consistência no desempenho dos alunos.

# %% [markdown]
# # 3) Imprima os resultados da estatística do teste Z, p value e indique se rejeitaremos ou não a hipótese nula. Justifique sua resposta.

# %%
# Tamanho das amostras
n = 50

# Fórmula Teste Z:
z = (media_amostragem_B - media_amostragem_A) / ((var_amostragem_A/n + var_amostragem_B/n)**0.5)

# p-value (teste unilateral)
p_value = 1 - stats.norm.cdf(z)

# Imprimir os resultados
print("Estatística de Teste Z:", z)
print("p-value:", p_value)

# Comparar o p-valor com o nível de significância
alpha = 0.05
if p_value < alpha:
    print("Rejeitamos a hipótese nula: a Estratégia B tem desempenho significativamente maior de ensino de matemática.")
else:
    print("Não rejeitamos a hipótese nula: não há evidências suficientes para concluir que a Estratégia B seja melhor no ensino de matemática.")
# Out:
# Estatística de Teste Z: 1.5267455833477102
# p-value: 0.06341214386181693
# Não rejeitamos a hipótese nula: não há evidências suficientes para concluir que a Estratégia B seja melhor no ensino de matemática.

# %% [markdown]
# - Neste caso, a hipótese nula **não será rejeitada**, pois o p-value **0.0634** (6.34%) **é maior que o nível de significância** da área crítica **0.05** (5%). Quando o p-value é maior que o nível de significância, a hipótese deve ser aceita (não rejeitar).

# %% [markdown]
# # 4) Para finalizar monte o gráfico da distribuição da estatística do nosso teste Z e explique o que pode ser observado através dele.

# %%
# Configurações do gráfico
fig, ax = plt.subplots(figsize=(10, 5))

# Valores de X e Y para plotar a distribuição
x = np.linspace(-3, 3, 1000)
# x = np.linspace(-3, 3, 1000): Esta linha cria um array x de 1000 pontos igualmente espaçados no intervalo de -3 a 3. Esse intervalo foi escolhido para abranger uma ampla gama de valores típicos para a estatística de teste Z, que segue uma distribuição normal padrão
y = stats.norm.pdf(x, 0, 1)
# y = stats.norm.pdf(x, 0, 1): Esta linha calcula os valores de densidade de probabilidade para cada ponto no array x com base na distribuição normal padrão.

# Plotando a distribuição normal padrão
ax.plot(x, y, label='Distribuição Normal Padrão')

# Marcação do valor observado da estatística do teste
ax.vlines(x=[z], ymin=0, ymax=stats.norm.pdf(z, 0, 1),
          colors='r', linestyles='dotted', label='Valor observado da estatística de teste')

# Área crítica
critical_region = stats.norm.ppf(0.025), stats.norm.ppf(0.975)
ax.fill_between(x, y, where=(x < critical_region[0]) | (x > critical_region[1]), color='gray', alpha=0.3, label='Área crítica')

# Legenda e rótulos
plt.legend()
plt.xlabel('Valor da Estatística de Teste Z')
plt.ylabel('Densidade')
plt.title('Distribuição da Estatística de Teste Z')
plt.grid(True)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# - Podemos verificar que o valor observado da estatística de teste, **1.5267455833477102**, se encontra **à direita** no gráfico, entre os pontos 1 e 2. Além disso, podemos ver que esse valor de z está de fato **fora da área crítica**, considerando o nível de significância de 0.05. Isso faz com que **não rejeitemos a hipótese nula**, pois o valor está fora da área de rejeição.
